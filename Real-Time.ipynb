# %% [markdown]
# https://catalog.data.gov/dataset?tags=real-time
#
# https://www.google.com/finance

# %%
import requests, re
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display, HTML
from pandas.io.json import json_normalize

# %%
#https://github.com/redklouds/Finviz-API/blob/master/finviz.py
request = requests.get('http://finviz.com/')

class FinViz:

    def __init__(self):
        """
        Function Name: Default Constructor
        PRECONDITIONS: None
        POSTCONDITIONS: 
            ->Initializes the object data at the current time
        ASSUMPTIONS: None
        """
        #make the request
        request = requests.get('http://finviz.com/')
        #maxe the soup
        soup = BeautifulSoup(request.text,'html5lib')
        #soup has been brewed
        self._html = soup
        #self._html = BeautifulSoup(requests.get('http://finviz.com/').text,'html5lib')
        self._data = list()


    def refresh(self):
        """
            Function Name: refresh
            Descriptions:
                -> Polls the webservice for new/updated data
            PRECONDITIONS: None
            POSTCONDITIONS: 
                -> Object reinitialized with new data
            ASSUMPTIONS: None
        """        
        self.__reinitalize__()
    
    def _reinitialize(self):
        """
            Function Name: (Helper) _reinitialize 
            Description:
                -> calls another get requsests to poll refreshed data manually
            PRECONDITIONS: None
            POSTCONDITIONS: 
                -> Refreshes data
            ASSUMPTIONS: None
        """        
        r = requests.get('http://finviz.com')
        self._html = BeautifulSoup(r.text)

    def _parseColumnData(self, data):
        """
            Function Name: 
            PRECONDITIONS:
            POSTCONDITIONS:
            ASSUMPTIONS:
        """        
        ret_data = data.findChild()
        ret_data = list(ret_data.children)
        result = list()
        for idx in ret_data:
            try:
                #parse the given data, into 
                result.append(self._parseText(idx.getText()))                
            except:
                #None Type, scrapping None Object, skip.
                pass
        return result  

    def _parseText(self, text):
        """
            Function Name: 
            PRECONDITIONS:
            POSTCONDITIONS:
            ASSUMPTIONS:
        """        
        #use regex for faster parsing of text, searching
        #for numbers and words, better and faster.

        #define regEx pattern
        #"find all alpha upper and lower words
        #+ one and unlimited timees
        #match words who may or may not have spcaes betweent hem and
        #are mixed caes zero to unliited times
        regExText = '[A-Z a-z]+'
        #match a number with at least 1 to unlimited length
        ##the number must have a period and 1 through 2 numbers after it
        #match fully if there is a '+' OR '-' ZERO or 1 times
        regExDigit = '(\+|-?\d+.\d{1,2})'
        #regExDigit = '(\d+.\d{1,2})'
        listText = re.findall(regExText, text)
        listDigit = re.findall(regExDigit, text)
        resultSet = {
                     'index':listText[0],
                     'price':listDigit[0],
                     'change':listDigit[1],
                     'volume':listDigit[2],
                     'signal':listText[1]
                     }
        #return the resulting dictionary
        return resultSet
    
    def getLeftColumn(self):
        """
            Function Name: getLeftColumn
            Description:
                -> get get's the raw data in the left column of the website
            PRECONDITIONS: None
            POSTCONDITIONS:
                ->returns a dictionary containing all the parsed data
                -> in the form:
                    Stock Index
                    Current Price
                    Percent Change
                    Volume
                    Signal
            ASSUMPTIONS: None
        """        
        data = self._getMainColumnData(0)
        a = self._parseColumnData(data)
        return a
        
    def getRightColumn(self):
        """
            Function Name: getLeftColumn
            Description:
                -> get get's the raw data in the right column of the website
            PRECONDITIONS: None
            POSTCONDITIONS:
                ->returns a dictionary containing all the parsed data
                -> in the form:
                    Earnings before
                    Stock Index
                    Current Price
                    Percent Change
                    Volume Signal
            ASSUMPTIONS: None
        """  
        data = self._getMainColumnData(1)
        a = self._parseColumnData(data)
        return a

    def _getMainColumnData(self,column):
        """
            Function Name: _getMainColumnData
            Description:
               -> our switch helper function depending on which 
               parameter we get, this function returns the respective data set
               pertaining to that column
               
            PRECONDITIONS: Integer 1 or 0( left will be 0, 1 will be right)
            POSTCONDITIONS:
                Left:
                Top Gainers
                New high
                Overbought
                Unusual Volume
                Upgrades
                Earnings Before
        
                The column on the right are:
                Top Losers
                New Low
                Oversold
                Most Volitile
                Most Active
                Downgrades
                Earnings After
                Insider Selling
            ASSUMPTIONS: None
        """        
        #scrape the specific elements
        searchResult = self._html.findAll('table', {'class':'t-home-table'})
        
        # we just want the first or second matches
        return searchResult[column]
        
    def marketStatus():
        """
            TODO: get Market status |Positive|Negative
            Function Name: 
            PRECONDITIONS:
            POSTCONDITIONS:
            ASSUMPTIONS:
        """        
        
    def getTrends(self):
        left_col = self.getLeftColumn()
        right_col = self.getRightColumn()
        
        combined_dict = list()
  
        for i in left_col:
            combined_dict.append(i)
        for i in right_col:
            combined_dict.append(i)
            
        #print(combined_dict)
        #return_dict = {"right_column": right_col, "left_column":left_col}
        return combined_dict


   
    def test():
        print("testing now")
        testObject = FinViz()

        data = testObject.getTrends()
        for i in data:
            print(i)
    

    if __name__ == "__main__":
        test()
# Out:
# testing now
# {'volume': u'682493', 'index': u'CMTA', 'price': u'14.51', 'signal': u'Top Gainers', 'change': u'40.33'}
# {'volume': u'2158533', 'index': u'LRN', 'price': u'23.39', 'signal': u'Top Gainers', 'change': u'34.94'}
# {'volume': u'6138765', 'index': u'TRVG', 'price': u'5.94', 'signal': u'Top Gainers', 'change': u'19.52'}
# {'volume': u'568916', 'index': u'IPAS', 'price': u'1.61', 'signal': u'Top Gainers', 'change': u'19.26'}
# {'volume': u'2834351', 'index': u'TUP', 'price': u'37.74', 'signal': u'Top Gainers', 'change': u'16.61'}
# {'volume': u'993323', 'index': u'TGA', 'price': u'2.36', 'signal': u'Top Gainers', 'change': u'16.26'}
# {'volume': u'2158533', 'index': u'LRN', 'price': u'23.39', 'signal': u'New High', 'change': u'34.94'}
# {'volume': u'709718', 'index': u'IMMY', 'price': u'3.74', 'signal': u'New High', 'change': u'-1.32'}
# {'volume': u'1255082', 'index': u'ZIXI', 'price': u'5.72', 'signal': u'New High', 'change': u'13.04'}
# {'volume': u'512634', 'index': u'ALLT', 'price': u'6.60', 'signal': u'New High', 'change': u'1.23'}
# {'volume': u'320253', 'index': u'JTPY', 'price': u'4.97', 'signal': u'Overbought', 'change': u'0.06'}
# {'volume': u'851957', 'index': u'ARII', 'price': u'69.90', 'signal': u'Overbought', 'change': u'0.07'}
# {'volume': u'8300573', 'index': u'NAUH', 'price': u'1.12', 'signal': u'Unusual Volume', 'change': u'119.63'}
# {'volume': u'7644079', 'index': u'AMRH', 'price': u'0.47', 'signal': u'Unusual Volume', 'change': u'-55.29'}
# {'volume': u'6141194', 'index': u'SGLB', 'price': u'1.37', 'signal': u'Unusual Volume', 'change': u'1.48'}
# {'volume': u'253322', 'index': u'VTC', 'price': u'80.04', 'signal': u'Unusual Volume', 'change': u'0.18'}
# {'volume': u'2792744', 'index': u'DDD', 'price': u'17.71', 'signal': u'Upgrades', 'change': u'6.11'}
# {'volume': u'446008', 'index': u'AB', 'price': u'29.00', 'signal': u'Earnings Before', 'change': u'-2.19'}
# {'volume': u'13777', 'index': u'BCBP', 'price': u'12.36', 'signal': u'Insider Buying', 'change': u'-3.15'}
# {'volume': u'7644079', 'index': u'AMRH', 'price': u'0.47', 'signal': u'Top Losers', 'change': u'-55.29'}
# {'volume': u'366375', 'index': u'TZOO', 'price': u'8.00', 'signal': u'Top Losers', 'change': u'-31.33'}
# {'volume': u'39462', 'index': u'ATV', 'price': u'22.92', 'signal': u'Top Losers', 'change': u'-28.82'}
# {'volume': u'867453', 'index': u'CIDM', 'price': u'1.03', 'signal': u'Top Losers', 'change': u'-24.78'}
# {'volume': u'2260897', 'index': u'NDLS', 'price': u'9.66', 'signal': u'Top Losers', 'change': u'-23.76'}
# {'volume': u'3296060', 'index': u'NTB', 'price': u'39.37', 'signal': u'Top Losers', 'change': u'-23.03'}
# {'volume': u'351003', 'index': u'SNSS', 'price': u'1.40', 'signal': u'New Low', 'change': u'-21.02'}
# {'volume': u'306988', 'index': u'LN', 'price': u'30.65', 'signal': u'New Low', 'change': u'-15.59'}
# {'volume': u'274104', 'index': u'LOVE', 'price': u'17.15', 'signal': u'New Low', 'change': u'-17.55'}
# {'volume': u'581148', 'index': u'HAFC', 'price': u'18.44', 'signal': u'New Low', 'change': u'-14.63'}
# {'volume': u'24122', 'index': u'TBIO', 'price': u'5.36', 'signal': u'Oversold', 'change': u'-1.83'}
# {'volume': u'1770182', 'index': u'SUM', 'price': u'12.56', 'signal': u'Oversold', 'change': u'-4.41'}
# {'volume': u'6141194', 'index': u'SGLB', 'price': u'1.37', 'signal': u'Most Volatile', 'change': u'1.48'}
# {'volume': u'5750748', 'index': u'PLAG', 'price': u'6.56', 'signal': u'Most Volatile', 'change': u'5.81'}
# {'volume': u'93010295', 'index': u'SPY', 'price': u'269.41', 'signal': u'Most Active', 'change': u'-1.54'}
# {'volume': u'90485717', 'index': u'T', 'price': u'30.78', 'signal': u'Most Active', 'change': u'-6.78'}
# {'volume': u'274233', 'index': u'ADSW', 'price': u'26.07', 'signal': u'Downgrades', 'change': u'-0.87'}
# {'volume': u'10065118', 'index': u'ABX', 'price': u'13.15', 'signal': u'Earnings After', 'change': u'-1.46'}
# {'volume': u'538875', 'index': u'ISRG', 'price': u'493.05', 'signal': u'Insider Selling', 'change': u'-2.74'}

# %%
print test

# %%
#html2df = FinViz(request)
html_df = FinViz.test()
display(HTML(html_df.to_html()))


#df = pd.DataFrame.from_dict(json_normalize(test), orient='columns')
#display(HTML(df.to_html()))
