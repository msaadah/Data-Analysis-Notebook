# %% [markdown]
# https://www.weatherbit.io/api/weather-forecast-48-hour

# %%
import urllib, json
from pandas.io.json import json_normalize
import pandas as pd
from IPython.display import display, HTML

# %%
url = "https://api.weatherbit.io/v2.0/forecast/hourly?city=Champaign,IL&key=b884eed1798f46feab4effc907e537a7&hours=1"
response = urllib.urlopen(url)
data = json.loads(response.read())
print data
# Out:
# {u'lon': u'-88.24338', u'lat': u'40.11642', u'country_code': u'US', u'city_name': u'Champaign', u'timezone': u'America/Chicago', u'state_code': u'IL', u'data': [{u'uv': 1.54297, u'timestamp_utc': u'2018-11-12T16:00:00', u'pop': 0, u'ts': 1542038400, u'vis': 24.1, u'weather': {u'code': 804, u'description': u'Overcast clouds', u'icon': u'c04d'}, u'pod': u'd', u'clouds_mid': 41, u'wind_cdir': u'N', u'dhi': 75.2866, u'dni': 844.763, u'snow': 0, u'rh': 79, u'pres': 998.422, u'snow_depth': 0, u'solar_rad': 117.272, u'timestamp_local': u'2018-11-12T10:00:00', u'wind_cdir_full': u'north', u'datetime': u'2018-11-12:16', u'wind_spd': 4.12983, u'wind_dir': 5, u'clouds': 100, u'temp': 2.7, u'app_temp': -1.5, u'clouds_hi': 100, u'wind_gust_spd': 7, u'slp': 1027.04, u'dewpt': -0.7, u'ozone': 308.454, u'precip': 0, u'clouds_low': 94, u'ghi': 469.089}]}

# %%
def get_row(url):
    #url = "https://api.weatherbit.io/v2.0/forecast/hourly?city=Champaign,IL&key=b884eed1798f46feab4effc907e537a7&hours=1"
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    columns = []
    data_list = []
    for key in data:
        value1= data[key]
        #print key+'---->'
        #print value1
    
        if isinstance(value1,list):
            for key2 in value1:
                #print key2 
                if isinstance(key2,dict):
                    for key3 in key2:
                #        print "**********" +key3+'---->'
                        value3 = key2[key3]
                        
                        
                        if isinstance(value3,dict):
                            for key4 in value3:
                                columns.append(key4)
                                data_list.append(value3[key4])
                 #               print "======================================"+key4 +'---->'
                 #               print "))))))))))))" + str(value3[key4])
                        else:
                            columns.append(key3)
                            data_list.append(value3)
                            #print columns
                  #          print " &&&&&&&&&&&&" +str(value3)
        else:
            columns.append(key)
            data_list.append(value1)
            #print columns
            #print value1

    return columns,data_list

#df = pd.DataFrame(data_list)
#df.head()

# %%
#forecast for one hour from different 
col,row= get_row("https://api.weatherbit.io/v2.0/forecast/hourly?city=Champaign,IL&key=b884eed1798f46feab4effc907e537a7&hours=1")
col,row2= get_row("https://api.weatherbit.io/v2.0/forecast/hourly?city=Newark,NJ&key=b884eed1798f46feab4effc907e537a7&hours=1")
col,row3= get_row("https://api.weatherbit.io/v2.0/forecast/hourly?city=LosAngeles,CA&key=b884eed1798f46feab4effc907e537a7&hours=1")
col,row4= get_row("https://api.weatherbit.io/v2.0/forecast/hourly?city=Denver,CO&key=b884eed1798f46feab4effc907e537a7&hours=1")


weather_data = [(row), (row2), (row3), (row4)]
labels = col
df = pd.DataFrame(weather_data, columns = labels)
df.head()
# Out:
#           lon       lat country_code    city_name             timezone  \
# 0   -88.24338  40.11642           US    Champaign      America/Chicago
# 1   -74.17237  40.73566           US       Newark     America/New_York
# 2  -118.24368  34.05223           US  Los Angeles  America/Los_Angeles
# 3   -104.9847  39.73915           US       Denver       America/Denver
#
#   state_code       uv        timestamp_utc  pop          ts   ...     temp  \
# 0         IL  1.54297  2018-11-12T16:00:00    0  1542038400   ...      2.7
# 1         NJ  5.12060  2018-11-12T16:00:00    0  1542038400   ...      4.9
# 2         CA  3.57917  2018-11-12T16:00:00    0  1542038400   ...     15.8
# 3         CO  1.25165  2018-11-12T16:00:00   20  1542038400   ...     -4.4
#
#    app_temp clouds_hi wind_gust_spd      slp  dewpt    ozone  precip  \
# 0      -1.5       100           7.0  1027.04   -0.7  308.454  0.0000
# 1       1.2         7           1.1  1030.75    1.0  279.354  0.0000
# 2      15.8         0           1.1  1024.27  -20.6  299.554  0.0000
# 3     -10.4         0           4.2  1041.55   -8.2  363.654  0.0625
#
#    clouds_low      ghi
# 0          94  469.089
# 1           5  523.399
# 2           0  235.595
# 3         100  358.339
#
# [4 rows x 40 columns]
