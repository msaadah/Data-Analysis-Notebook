# %% [markdown]
# https://catalog.data.gov/dataset?tags=real-time
#
# https://www.google.com/finance

# %%
import requests, re
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display, HTML
from pandas.io.json import json_normalize

#https://github.com/redklouds/Finviz-API/blob/master/finviz.py
#request = requests.get('http://finviz.com/')

class FinViz:

    def __init__(self):
        """
        Function Name: Default Constructor
        PRECONDITIONS: None
        POSTCONDITIONS: 
            ->Initializes the object data at the current time
        ASSUMPTIONS: None
        """
        #make the request
        request = requests.get('http://finviz.com/')
        #maxe the soup
        soup = BeautifulSoup(request.text,'html5lib')
        #soup has been brewed
        self._html = soup
        #self._html = BeautifulSoup(requests.get('http://finviz.com/').text,'html5lib')
        self._data = list()


    def refresh(self):
        """
            Function Name: refresh
            Descriptions:
                -> Polls the webservice for new/updated data
            PRECONDITIONS: None
            POSTCONDITIONS: 
                -> Object reinitialized with new data
            ASSUMPTIONS: None
        """        
        self.__reinitialize()
    
    def __reinitialize(self):
        """
            Function Name: (Helper) _reinitialize 
            Description:
                -> calls another get requsests to poll refreshed data manually
            PRECONDITIONS: None
            POSTCONDITIONS: 
                -> Refreshes data
            ASSUMPTIONS: None
        """        
        request = requests.get('http://finviz.com/')
        #maxe the soup
        soup = BeautifulSoup(request.text,'html5lib')
        #soup has been brewed
        self._html = soup
        #self._html = BeautifulSoup(requests.get('http://finviz.com/').text,'html5lib')
        self._data = list()


    def _parseColumnData(self, data):
        """
            Function Name: 
            PRECONDITIONS:
            POSTCONDITIONS:
            ASSUMPTIONS:
        """        
        ret_data = data.findChild()
        ret_data = list(ret_data.children)
        result = list()
        for idx in ret_data:
            try:
                #parse the given data, into 
                result.append(self._parseText(idx.getText()))                
            except:
                #None Type, scrapping None Object, skip.
                pass
        return result  

    def _parseText(self, text):
        """
            Function Name: 
            PRECONDITIONS:
            POSTCONDITIONS:
            ASSUMPTIONS:
        """        
        #use regex for faster parsing of text, searching
        #for numbers and words, better and faster.

        #define regEx pattern
        #"find all alpha upper and lower words
        #+ one and unlimited timees
        #match words who may or may not have spcaes betweent hem and
        #are mixed caes zero to unliited times
        regExText = '[A-Z a-z]+'
        #match a number with at least 1 to unlimited length
        ##the number must have a period and 1 through 2 numbers after it
        #match fully if there is a '+' OR '-' ZERO or 1 times
        regExDigit = '(\+|-?\d+.\d{1,2})'
        #regExDigit = '(\d+.\d{1,2})'
        listText = re.findall(regExText, text)
        listDigit = re.findall(regExDigit, text)
        resultSet = {
                     'index':listText[0],
                     'price':listDigit[0],
                     'change':listDigit[1],
                     'volume':listDigit[2],
                     'signal':listText[1]
                     }
        #return the resulting dictionary
        return resultSet
    
    def getLeftColumn(self):
        """
            Function Name: getLeftColumn
            Description:
                -> get get's the raw data in the left column of the website
            PRECONDITIONS: None
            POSTCONDITIONS:
                ->returns a dictionary containing all the parsed data
                -> in the form:
                    Stock Index
                    Current Price
                    Percent Change
                    Volume
                    Signal
            ASSUMPTIONS: None
        """        
        data = self._getMainColumnData(0)
        a = self._parseColumnData(data)
        return a
        
    def getRightColumn(self):
        """
            Function Name: getLeftColumn
            Description:
                -> get get's the raw data in the right column of the website
            PRECONDITIONS: None
            POSTCONDITIONS:
                ->returns a dictionary containing all the parsed data
                -> in the form:
                    Earnings before
                    Stock Index
                    Current Price
                    Percent Change
                    Volume Signal
            ASSUMPTIONS: None
        """  
        data = self._getMainColumnData(1)
        a = self._parseColumnData(data)
        return a

    def _getMainColumnData(self,column):
        """
            Function Name: _getMainColumnData
            Description:
               -> our switch helper function depending on which 
               parameter we get, this function returns the respective data set
               pertaining to that column
               
            PRECONDITIONS: Integer 1 or 0( left will be 0, 1 will be right)
            POSTCONDITIONS:
                Left:
                Top Gainers
                New high
                Overbought
                Unusual Volume
                Upgrades
                Earnings Before
        
                The column on the right are:
                Top Losers
                New Low
                Oversold
                Most Volitile
                Most Active
                Downgrades
                Earnings After
                Insider Selling
            ASSUMPTIONS: None
        """        
        #scrape the specific elements
        searchResult = self._html.findAll('table', {'class':'t-home-table'})
        
        # we just want the first or second matches
        return searchResult[column]
        
    def marketStatus():
        """
            TODO: get Market status |Positive|Negative
            Function Name: 
            PRECONDITIONS:
            POSTCONDITIONS:
            ASSUMPTIONS:
        """        
        pass
    def getTrends(self):
        left_col = self.getLeftColumn()
        right_col = self.getRightColumn()
        
        combined_dict = list()
  
        for i in left_col:
            combined_dict.append(i)
        for i in right_col:
            combined_dict.append(i)
            
        #print(combined_dict)
        #return_dict = {"right_column": right_col, "left_column":left_col}
        return combined_dict

# %%
testObject = FinViz()
data = testObject.getTrends()
df = pd.DataFrame(data)
df['change'] = df['change'].astype(float)
df['price'] = df['price'].astype(float)
df['volume'] = df['volume'].astype(int)
df.head()
# Out:
# testing now
#    change index   price       signal    volume
# 0   44.36   RHT  168.44  Top Gainers  24482849
# 1   28.98  DCIX    2.27  Top Gainers  11438617
# 2   22.20  CASI    3.38  Top Gainers    544197
# 3   21.79  KNDI    4.87  Top Gainers   1618000
# 4   20.33   CTB   30.63  Top Gainers   2175533

# %%
testObject.refresh()
data = testObject.getTrends()
df2 = pd.DataFrame(data)
df2['change'] = df2['change'].astype(float)
df2['price'] = df2['price'].astype(float)
df2['volume'] = df2['volume'].astype(int)
df2.head()
# Out:
#    change index   price       signal    volume
# 0   44.58   RHT  168.70  Top Gainers  25144162
# 1   28.98  DCIX    2.27  Top Gainers  11517408
# 2   19.88  TOPS    1.99  Top Gainers   6661967
# 3   19.86  CASI    3.32  Top Gainers    560787
# 4   19.69   CTB   30.46  Top Gainers   2238538

# %%
df.index
# Out:
# RangeIndex(start=0, stop=38, step=1)

# %%
import math
import random
import matplotlib.pyplot as plt

price = df['price']
price2 = df2['price']
x = df['index']
fig = plt.figure(figsize=(7,7)) 

plt.plot(price,x, price2,x)
#plt.savefig('test.png')
plt.show()

# %%
#plot price of df vs df2

import math
import random
import matplotlib.pyplot as plt

price = df['price'] - df2['price']
price2 = df2['price']
x = df['index']
fig = plt.figure(figsize=(7,7)) 

plt.plot(price, x)
#plt.savefig('test.png')
plt.show()

# %%
group = df2.groupby(["signal"])
for key,item in group:
    display(HTML(group.get_group(key).to_html()))
    
df2['signal'].value_counts()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>-0.62</td>
#       <td>AMAT</td>
#       <td>32.16</td>
#       <td>Downgrades</td>
#       <td>5023384</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>36</th>
#       <td>2.49</td>
#       <td>AEIS</td>
#       <td>45.32</td>
#       <td>Earnings After</td>
#       <td>182876</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>17</th>
#       <td>-1.68</td>
#       <td>AMG</td>
#       <td>113.59</td>
#       <td>Earnings Before</td>
#       <td>669765</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18</th>
#       <td>1.29</td>
#       <td>HY</td>
#       <td>60.65</td>
#       <td>Insider Buying</td>
#       <td>16037</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>37</th>
#       <td>-0.83</td>
#       <td>ETV</td>
#       <td>14.48</td>
#       <td>Insider Selling</td>
#       <td>362061</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>33</th>
#       <td>0.76</td>
#       <td>SPY</td>
#       <td>267.35</td>
#       <td>Most Active</td>
#       <td>67589367</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>4.26</td>
#       <td>F</td>
#       <td>9.36</td>
#       <td>Most Active</td>
#       <td>60123022</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>31</th>
#       <td>15.32</td>
#       <td>UUU</td>
#       <td>1.43</td>
#       <td>Most Volatile</td>
#       <td>4349444</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>2.19</td>
#       <td>CCCL</td>
#       <td>2.34</td>
#       <td>Most Volatile</td>
#       <td>1115885</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>6.22</td>
#       <td>NTWK</td>
#       <td>8.92</td>
#       <td>New High</td>
#       <td>167564</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.90</td>
#       <td>JTPY</td>
#       <td>5.03</td>
#       <td>New High</td>
#       <td>289576</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>5.78</td>
#       <td>SMP</td>
#       <td>53.44</td>
#       <td>New High</td>
#       <td>121342</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1.91</td>
#       <td>AMRN</td>
#       <td>22.38</td>
#       <td>New High</td>
#       <td>8248546</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>25</th>
#       <td>-16.43</td>
#       <td>MLNT</td>
#       <td>2.34</td>
#       <td>New Low</td>
#       <td>890728</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>-17.52</td>
#       <td>TSEM</td>
#       <td>14.64</td>
#       <td>New Low</td>
#       <td>3276582</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>-5.26</td>
#       <td>CHFS</td>
#       <td>0.90</td>
#       <td>New Low</td>
#       <td>121619</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>-8.48</td>
#       <td>FWP</td>
#       <td>1.51</td>
#       <td>New Low</td>
#       <td>26061</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>0.90</td>
#       <td>JTPY</td>
#       <td>5.03</td>
#       <td>Overbought</td>
#       <td>289576</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.01</td>
#       <td>ARII</td>
#       <td>69.93</td>
#       <td>Overbought</td>
#       <td>162947</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>29</th>
#       <td>0.21</td>
#       <td>FLEX</td>
#       <td>7.11</td>
#       <td>Oversold</td>
#       <td>15326133</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>0.16</td>
#       <td>LOB</td>
#       <td>18.75</td>
#       <td>Oversold</td>
#       <td>155070</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>42.72</td>
#       <td>RHT</td>
#       <td>166.52</td>
#       <td>Top Gainers</td>
#       <td>22556202</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>31.25</td>
#       <td>DCIX</td>
#       <td>2.31</td>
#       <td>Top Gainers</td>
#       <td>10605261</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>23.10</td>
#       <td>CASI</td>
#       <td>3.41</td>
#       <td>Top Gainers</td>
#       <td>493196</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19.84</td>
#       <td>CTB</td>
#       <td>30.50</td>
#       <td>Top Gainers</td>
#       <td>1911390</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17.25</td>
#       <td>KNDI</td>
#       <td>4.69</td>
#       <td>Top Gainers</td>
#       <td>1363181</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>16.89</td>
#       <td>TOPS</td>
#       <td>1.94</td>
#       <td>Top Gainers</td>
#       <td>5525368</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>-22.39</td>
#       <td>YECO</td>
#       <td>5.57</td>
#       <td>Top Losers</td>
#       <td>973886</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>-18.16</td>
#       <td>DNR</td>
#       <td>3.56</td>
#       <td>Top Losers</td>
#       <td>21957609</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>-17.52</td>
#       <td>TSEM</td>
#       <td>14.64</td>
#       <td>Top Losers</td>
#       <td>3276582</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>-16.43</td>
#       <td>MLNT</td>
#       <td>2.34</td>
#       <td>Top Losers</td>
#       <td>890728</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>-14.81</td>
#       <td>FDC</td>
#       <td>18.40</td>
#       <td>Top Losers</td>
#       <td>30829593</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>-14.12</td>
#       <td>MYND</td>
#       <td>1.46</td>
#       <td>Top Losers</td>
#       <td>268760</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12</th>
#       <td>0.35</td>
#       <td>HYUP</td>
#       <td>47.93</td>
#       <td>Unusual Volume</td>
#       <td>14101</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>15.32</td>
#       <td>UUU</td>
#       <td>1.43</td>
#       <td>Unusual Volume</td>
#       <td>4349444</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.64</td>
#       <td>PBS</td>
#       <td>29.97</td>
#       <td>Unusual Volume</td>
#       <td>406611</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.00</td>
#       <td>SFBC</td>
#       <td>36.05</td>
#       <td>Unusual Volume</td>
#       <td>46508</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>change</th>
#       <th>index</th>
#       <th>price</th>
#       <th>signal</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>16</th>
#       <td>2.92</td>
#       <td>ANCX</td>
#       <td>25.76</td>
#       <td>Upgrades</td>
#       <td>59380</td>
#     </tr>
#   </tbody>
# </table>
# Top Losers         6
# Top Gainers        6
# New High           4
# Unusual Volume     4
# New Low            4
# Most Volatile      2
# Overbought         2
# Oversold           2
# Most Active        2
# Upgrades           1
# Earnings Before    1
# Insider Buying     1
# Earnings After     1
# Downgrades         1
# Insider Selling    1
# Name: signal, dtype: int64

# %%
#trying one-way anova

import statsmodels.api as sm
from statsmodels.formula.api import ols
 
mod = ols('change ~ price',
                data=data).fit()
                
aov_table = sm.stats.anova_lm(mod, typ=2)
print aov_table
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-9aa70e59ff71> in <module>()
#       5
#       6 mod = ols('change ~ price',
# ----> 7                 data=data).fit()
#       8
#       9 aov_table = sm.stats.anova_lm(mod, typ=2)
#
# C:\Anaconda\lib\site-packages\statsmodels\base\model.pyc in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# C:\Anaconda\lib\site-packages\statsmodels\formula\formulatools.pyc in handle_formula_data(Y, X, formula, depth, missing)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 68                                NA_action=na_action)
#      69
#      70     # if missing == 'raise' there's not missing_mask
#
# C:\Anaconda\lib\site-packages\patsy\highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# C:\Anaconda\lib\site-packages\patsy\highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# C:\Anaconda\lib\site-packages\patsy\highlevel.pyc in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# C:\Anaconda\lib\site-packages\patsy\build.pyc in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# C:\Anaconda\lib\site-packages\patsy\build.pyc in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# C:\Anaconda\lib\site-packages\patsy\eval.pyc in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# C:\Anaconda\lib\site-packages\patsy\eval.pyc in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# C:\Anaconda\lib\site-packages\patsy\compat.pyc in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      34 def call_and_wrap_exc(msg, origin, f, *args, **kwargs):
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#      38         if sys.version_info[0] >= 3:
#
# C:\Anaconda\lib\site-packages\patsy\eval.pyc in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#     168     @classmethod
#
# <string> in <module>()
#
# C:\Anaconda\lib\site-packages\patsy\eval.pyc in __getitem__(self, key)
#      46         for d in self._dicts:
#      47             try:
# ---> 48                 return d[key]
#      49             except KeyError:
#      50                 pass
#
# C:\Anaconda\lib\site-packages\patsy\eval.pyc in __getitem__(self, key)
#      46         for d in self._dicts:
#      47             try:
# ---> 48                 return d[key]
#      49             except KeyError:
#      50                 pass
#
# TypeError: list indices must be integers, not str

# %%
import scipy.stats as ss
for name_group in df.groupby(['signal']):
    samples = df['price'] 
    for condition in name_group[1].groupby(['signal']):
        f_val , p_val = ss.f_oneway(*samples)
        print('Name: {}, F value: {:.3f}, p value: {:.3f}'.format(name_group[0], f_val, p_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6529b436bc58> in <module>()
#       3     samples = df['price']
#       4     for condition in name_group[1].groupby(['signal']):
# ----> 5         f_val , p_val = ss.f_oneway(*samples)
#       6         print('Name: {}, F value: {:.3f}, p value: {:.3f}'.format(name_group[0], f_val, p_val))
#
# C:\Anaconda\lib\site-packages\scipy\stats\stats.pyc in f_oneway(*args)
#    2908     # ANOVA on N groups, each in its own array
#    2909     num_groups = len(args)
# -> 2910     alldata = np.concatenate(args)
#    2911     bign = len(alldata)
#    2912
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
# %%html
# testObject._html
# display(HTML(str(testObject._html)))
# Out:
# testObject._html
# display(HTML(str(testObject._html)))

# %%
# %whos          #gives variable and types used
# %lsmagic       #commands
# Out:
# Variable         Type               Data/Info
# ---------------------------------------------
# BeautifulSoup    type               <class 'bs4.BeautifulSoup'>
# FinViz           classobj           __main__.FinViz
# HTML             type               <class 'IPython.core.display.HTML'>
# data             list               n=38
# df               DataFrame              change index   price <...>Insider Selling    340824
# df2              DataFrame              change index   price <...>Insider Selling    340824
# display          function           <function display at 0x0000000002C55F98>
# json_normalize   function           <function json_normalize at 0x00000000082D3518>
# pd               module             <module 'pandas' from 'C:<...>ges\pandas\__init__.pyc'>
# re               module             <module 're' from 'C:\Anaconda\lib\re.pyc'>
# requests         module             <module 'requests' from '<...>s\requests\__init__.pyc'>
# testObject       __main__.FinViz    <__main__.FinViz instance at 0x0000000003CB9EC8>

# %% [markdown]
# make a list for each category (ie volume, index, etc) and append the values associated with them. then make a dictionary containing all of the lists and add that to a dataframe
